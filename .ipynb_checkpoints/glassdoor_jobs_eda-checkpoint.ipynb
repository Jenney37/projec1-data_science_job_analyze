# %% [markdown]
# ### 3. EDA
# This part is going to

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.preprocessing import PolynomialFeatures
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
import sklearn.metrics as skm
from sklearn.model_selection import train_test_split
import operator as op

from sklearn.impute import SimpleImputer

import seaborn as sns

# %%
df = pd.read_csv('/Users/liminzhenscc/Documents/study/python_data_analyze/project/2data_sc_salary/glassdoor_jobs_cleaned.csv')
df.drop('Unnamed: 0', axis=1, inplace= True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1173 entries, 0 to 1172
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          1173 non-null   object
#  1   Salary Estimate    1173 non-null   object
#  2   Job Description    1173 non-null   object
#  3   Rating             1173 non-null   float64
#  4   Company Name       1173 non-null   object
#  5   Location           1173 non-null   object
#  6   Size               1173 non-null   object
#  7   Founded            1173 non-null   int64
#  8   Type of ownership  1173 non-null   object
#  9   Industry           1173 non-null   object
#  10  Sector             1173 non-null   object
#  11  Revenue            1173 non-null   object
#  12  min_salary         1173 non-null   int64
#  13  max_salary         1173 non-null   int64
#  14  ave_salary         1173 non-null   float64
#  15  company_name       1173 non-null   object
#  16  age                1173 non-null   int64
#  17  python_yn          1173 non-null   int64
#  18  r_yn               1173 non-null   int64
#  19  ML_yn              1173 non-null   int64
#  20  excel_yn           1173 non-null   int64
#  21  spark_yn           1173 non-null   int64
#  22  aws_yn             1173 non-null   int64
#  23  graduate_yn        1173 non-null   int64
# dtypes: float64(2), int64(11), object(11)
# memory usage: 220.1+ KB

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'min_salary', 'max_salary',
#        'ave_salary', 'company_name', 'age', 'python_yn', 'r_yn', 'ML_yn',
#        'excel_yn', 'spark_yn', 'aws_yn', 'graduate_yn'],
#       dtype='object')

# %%
title=df['Job Title'].value_counts(sort=True).index.to_list()
title
# Out:
# ['Data Scientist',
#  'Data Masking Specialist',
#  'Business Intelligence (BI) & Data Warehouse Developer',
#  'Graduate / Cadet Environmental Planner / Scientist',
#  'Quantitative Researcher',
#  'EL 1 (S&T Level 5) - AI/ML Researcher for Adaptive Situational Awareness and Decision Making',
#  'Graduate - Technology Associate - Canberra',
#  'Graduate Data Science - Brisbane (Corporate)',
#  'BI Analyst',
#  'Quantum Researcher, Experiment (all levels)',
#  'Data Scientists | Simulation | Deep Learning |Baseline | Join VSG Today!',
#  'Graduate Machine Learning (Canberra based)',
#  'Data Science Graduate/Undergraduate - Immed Start!',
#  'Data & Analytics RA3D - Expression of interest',
#  'Research Scientist (Cell Line Development Scientist)',
#  'Software Developers (Real-time Simulation & Machine Technology) – all experience levels, full and part-time',
#  'Consulting - Climate and Sustainability - 2022/23 Graduate Program (Brisbane)',
#  'Expression of Interest - FPGA Hardware Developer',
#  'Big Data Developer',
#  'Research Associate - Data Science',
#  'Senior Data and Policy Analyst',
#  'Data Scientist 3-6 month Contract',
#  'Quantitative Analyst - 99.9% Need Not Apply',
#  'Consulting - Data & AI - 2022/23 Summer Vacationer Program (Canberra)',
#  'Data Scientist (Simulation)',
#  'APS Level 4/5-6 (S&T Level 3-4) - Food Science Researcher',
#  'SVP 2022/2023 - Digital - Data Science',
#  'Data Analyst - Credit & Fraud Risk',
#  'APS 4/5-6 (S&T Level 3-4) - AI and Data Scientist',
#  'APS Level 4/5-6 (S&T Level 3-4) - Researcher – Space Structures',
#  'Data Science and Machine Learning Consultant / Manager',
#  'Expression of Interest - Data Operations Technician',
#  'Consultant / Senior Consultant - Strategy - Data & AI',
#  'Data & Analytics Opportunities | Canberra',
#  'Consulting - Data & AI - 2022/23 Graduate Program (Canberra)',
#  'Research Officer (HEAL)',
#  'EOI - Senior Business/Data Analyst - Decision Science & Analytics (Sydney)',
#  'Data and Policy Analyst',
#  'Machine Learning Scientist',
#  'Data Analyst',
#  'Data Migration Specialist - Brisbane or Canberra',
#  'Systems Administrator',
#  'Senior Analyst Programmer AS/400',
#  'ICT Business Analyst - Data',
#  'Business Intelligence Analyst',
#  '2023 Nearmap Graduate Program - AI Systems (Machine Learning)',
#  'Business Intelligence (BI) Developer',
#  'DATA SCIENTIST - CUSTOMER OPERATIONS',
#  'Superannuation Data Analyst',
#  'Environmental Analyst (Graduate)',
#  'Graduate Analyst, Data and Analytics',
#  'Data and Analytics Consultant',
#  'Senior Business Analyst',
#  'Systems Analyst',
#  'Senior BI Developer',
#  'Junior Data Analyst - Western Public Health Unit',
#  'Information Technology Support',
#  'ICT Business Analyst',
#  'Data Science Engineer - Tech Company',
#  'Network Planning Analyst (APAC)',
#  'Data & Analytics Manager',
#  'Data Operations Analyst',
#  'Alteryx Data Science',
#  'Data Engineer',
#  'Data Centre Technician - Multiple Opportunities',
#  'Algorithmic Trading Software Developer',
#  'Data & AI Opportunities | Perth',
#  'Junior Data Analyst',
#  'City Researcher',
#  'Instructor - Part Time Data Science',
#  'Data Scientist - Australian Citizen',
#  'Graduate - Technology Associate - Melbourne',
#  'Junior Machine Learning Engineer',
#  'Data Scientist (x2)',
#  'Head of Data Science',
#  'Sustainability Data Analyst',
#  'Technology Graduate - 2023',
#  'Data Graduates, Australian Government',
#  'Data and Reporting Analyst',
#  'Junior Data Engineer Job in Gold Coast',
#  'Data Scientist (Optimization Focused)',
#  'Geospatial Data Analyst',
#  'Junior Python Developer',
#  'Junior Data Engineer',
#  'Data Migration Specialist / Lead',
#  'Graduate Environmental Scientist',
#  'Scientist (Remote Sensing)',
#  'Data scientist',
#  'Pricing Data Scientist',
#  'Maximo Data Migration',
#  'Data Analyst, Compliance',
#  'Data & Reporting Specialist',
#  'Graduate Software Developer',
#  'Forensic Technology - 2023 Graduate Program (Sydney)',
#  'Artificial Intelligence- Virtual Assistant & NLP Data Scientist']

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='Job Title', data=df, order=df['Job Title'].value_counts().index)
plt.xticks(rotation=45)
plt.show()

# %%
#simplify job title
def simp_title(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'machine learning' in title.lower():
        return 'machine learning'
    elif 'data masking' in title.lower():
        return 'data masking'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'consulting' in title.lower():
        return 'consulting'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'research' in title.lower() or 'researcher' in title.lower():
        return 'research'
    elif 'business information' in title.lower() or 'bi' in title.lower():
        return 'business information'
    else:
        return 'na'
#difine the function to decide level of these job
def level(title):
    if 'sr' in title.lower() or 'sr.' in title.lower() or 'senior' in title.lower() or 'principal' in title.lower() or 'lead' in title.lower() or 'head' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'junior' in title.lower() or 'jr.' in title.lower():
        return 'junior'
    else:
        return 'na'

# %%
df.job_simp = df['Job Title'].apply(simp_title)
df.job_level = df['Job Title'].apply(level)

# %%
df.job_level.value_counts()
# Out:
# na        1108
# senior      58
# junior       7
# Name: Job Title, dtype: int64

# %%
df.job_simp.value_counts()
# Out:
# na                      334
# data scientist          212
# research                210
# analyst                 162
# business information     71
# consulting               67
# machine learning         59
# data masking             54
# data engineer             4
# Name: Job Title, dtype: int64

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='Location', data=df)
plt.xticks(rotation=-45)
plt.show()

# %%
cities = df.Location.value_counts().index.to_list()
len(cities)
# Out:
# 29

# %% [markdown]
# overall there are several jobs located in 29 different cities, i need to find the state of those cities

# %%
#job description length
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Science Graduate/Undergraduate - Immed St...
# 1       Graduate Data Science - Brisbane (Corporate)
# 2  Consulting - Data & AI - 2022/23 Summer Vacati...
# 3                                     Data Scientist
# 4                  Research Associate - Data Science
#
#                  Salary Estimate  \
# 0  $97K - $141K (Glassdoor Est.)
# 1  $97K - $141K (Glassdoor Est.)
# 2  $97K - $141K (Glassdoor Est.)
# 3  $97K - $141K (Glassdoor Est.)
# 4  $97K - $141K (Glassdoor Est.)
#
#                                      Job Description  Rating  \
# 0  Be part of the Award Winning CIMIC Graduate Pr...     3.8
# 1  Job Number:\n82295\nWork type:\nPermanent - Fu...     3.7
# 2  Date: 18-Jul-2022\n\nLocation:\nCanberra, ACT,...     4.0
# 3  Maltem is a community of 1,200+ passionate ind...     3.8
# 4  Job no: 510607\nWork type: Full time\nLocation...     4.2
#
#                          Company Name     Location                     Size  \
# 0                    UGL Limited\n3.8  North Shore  5001 to 10000 Employees
# 1                        Aurizon\n3.7     Brisbane   1001 to 5000 Employees
# 2                       Deloitte\n4.0     Canberra         10000+ Employees
# 3               MALTEM Australia\n3.8       Sydney   1001 to 5000 Employees
# 4  University of New South Wales\n4.2       Sydney   1001 to 5000 Employees
#
#    Founded               Type of ownership                 Industry  ...  \
# 0     1984  Subsidiary or Business Segment             Construction  ...
# 1     2009                Company - Public      Taxi & Car Services  ...
# 2     1850               Company - Private         Accounting & Tax  ...
# 3     2001               Company - Private      Business Consulting  ...
# 4     1949            College / University  Colleges & Universities  ...
#
#                     company_name  age  python_yn  r_yn  ML_yn excel_yn  \
# 0                    UGL Limited   38          0     1      0        1
# 1                        Aurizon   13          0     1      1        0
# 2                       Deloitte  172          0     1      1        1
# 3               MALTEM Australia   21          0     1      0        0
# 4  University of New South Wales   73          1     1      1        0
#
#    spark_yn  aws_yn  graduate_yn  desc_len
# 0         0       0            1      2319
# 1         0       0            1      4012
# 2         0       0            0      3348
# 3         0       0            0       753
# 4         0       0            0      6499
#
# [5 rows x 25 columns]

# %% [markdown]
# #### start to visualize datasets

# %%
df.describe()
# Out:
#             Rating      Founded   min_salary   max_salary   ave_salary  \
# count  1173.000000  1173.000000  1173.000000  1173.000000  1173.000000
# mean      2.755243   859.845695    90.757033   120.281330   105.519182
# std       2.193973   975.915977    52.707219    36.889018    44.192154
# min      -1.000000    -1.000000    36.000000    82.000000    66.000000
# 25%       2.300000    -1.000000    36.000000    96.000000    66.000000
# 50%       3.800000    -1.000000   106.000000   120.000000   113.000000
# 75%       4.000000  1981.000000   106.000000   120.000000   113.000000
# max       5.000000  2019.000000   240.000000   240.000000   240.000000
#
#                age    python_yn    r_yn        ML_yn     excel_yn  \
# count  1173.000000  1173.000000  1173.0  1173.000000  1173.000000
# mean     25.056266     0.413470     1.0     0.361466     0.381927
# std      48.627584     0.492666     0.0     0.480630     0.486066
# min      -1.000000     0.000000     1.0     0.000000     0.000000
# 25%      -1.000000     0.000000     1.0     0.000000     0.000000
# 50%      -1.000000     0.000000     1.0     0.000000     0.000000
# 75%      28.000000     1.000000     1.0     1.000000     1.000000
# max     173.000000     1.000000     1.0     1.000000     1.000000
#
#           spark_yn       aws_yn  graduate_yn     desc_len
# count  1173.000000  1173.000000  1173.000000  1173.000000
# mean      0.048593     0.066496     0.197783  3109.450128
# std       0.215108     0.249254     0.398498  1662.164423
# min       0.000000     0.000000     0.000000   274.000000
# 25%       0.000000     0.000000     0.000000  1985.000000
# 50%       0.000000     0.000000     0.000000  3285.000000
# 75%       0.000000     0.000000     0.000000  3909.000000
# max       1.000000     1.000000     1.000000  9126.000000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Size', 'Founded', 'Type of ownership',
#        'Industry', 'Sector', 'Revenue', 'min_salary', 'max_salary',
#        'ave_salary', 'company_name', 'age', 'python_yn', 'r_yn', 'ML_yn',
#        'excel_yn', 'spark_yn', 'aws_yn', 'graduate_yn', 'desc_len'],
#       dtype='object')

# %%
sns.histplot(df.Rating, color='pink')
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='Count'>

# %%
sns.histplot(df.ave_salary)
# Out:
# <AxesSubplot:xlabel='ave_salary', ylabel='Count'>

# %%
df.ave_salary.value_counts()
# Out:
# 113.0    573
# 66.0     330
# 88.5      90
# 240.0     90
# 68.5      60
# 119.0     30
# Name: ave_salary, dtype: int64
