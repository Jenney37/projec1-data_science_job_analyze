# %% [markdown]
# ### 3. EDA
# This part is going to

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.preprocessing import PolynomialFeatures
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
import sklearn.metrics as skm
from sklearn.model_selection import train_test_split
import operator as op

from sklearn.impute import SimpleImputer

import seaborn as sns

# %%
df = pd.read_csv('/Users/liminzhenscc/Documents/study/python_data_analyze/project/2data_sc_salary/glassdoor_jobs_cleaned2.csv')
df.drop('Unnamed: 0', axis=1, inplace= True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1261 entries, 0 to 1260
# Data columns (total 25 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          1261 non-null   object
#  1   Salary Estimate    1261 non-null   object
#  2   Average Salary     1261 non-null   object
#  3   Job Description    1261 non-null   object
#  4   Rating             1261 non-null   float64
#  5   Company Name       1261 non-null   object
#  6   Location           1261 non-null   object
#  7   Size               1261 non-null   object
#  8   Founded            1261 non-null   int64
#  9   Type of ownership  1261 non-null   object
#  10  Industry           1261 non-null   object
#  11  Sector             1261 non-null   object
#  12  Revenue            1261 non-null   object
#  13  min_salary         1261 non-null   int64
#  14  max_salary         1261 non-null   int64
#  15  company_name       1261 non-null   object
#  16  age                1261 non-null   int64
#  17  python_yn          1261 non-null   int64
#  18  r_yn               1261 non-null   int64
#  19  ML_yn              1261 non-null   int64
#  20  excel_yn           1261 non-null   int64
#  21  spark_yn           1261 non-null   int64
#  22  aws_yn             1261 non-null   int64
#  23  graduate_yn        1261 non-null   int64
#  24  ave_salary         1261 non-null   float64
# dtypes: float64(2), int64(11), object(12)
# memory usage: 246.4+ KB

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Average Salary', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'min_salary',
#        'max_salary', 'company_name', 'age', 'python_yn', 'r_yn', 'ML_yn',
#        'excel_yn', 'spark_yn', 'aws_yn', 'graduate_yn', 'ave_salary'],
#       dtype='object')

# %%
title=df['Job Title'].value_counts(sort=True).index.to_list()
title
# Out:
# ['Data Scientist',
#  'Junior Data Analyst - Western Public Health Unit',
#  'Business Intelligence (BI) & Data Warehouse Developer',
#  'Software Developers (Real-time Simulation & Machine Technology) – all experience levels, full and part-time',
#  'Senior Software Engineer, Site Reliability Engineering - Job Seeker',
#  'Software Developer',
#  'Data Science Graduate/Undergraduate - Immed Start!',
#  'Graduate Data Science - Brisbane (Corporate)',
#  'Technology Graduate - 2023',
#  'Data Scientists | Simulation | Deep Learning |Baseline | Join VSG Today!',
#  'Consulting - Data & AI - 2022/23 Summer Vacationer Program (Canberra)',
#  'EOI - Senior Business/Data Analyst - Decision Science & Analytics (Sydney)',
#  'Data Graduates, Australian Government',
#  'Algorithmic Trading Software Developer',
#  'Mergers & Acquisitions (iDeal) - 2023 Graduate Program (Sydney)',
#  'Mergers & Acquisitions - 2023 Graduate Program (Perth)',
#  'Data Scientist (Optimization Focused)',
#  'Forensic Technology - 2023 Graduate Program (Sydney)',
#  'Artificial Intelligence- Virtual Assistant & NLP Data Scientist',
#  'Graduate - Technology Associate - Sydney',
#  'Data Science and Machine Learning Consultant / Manager',
#  'Analyst - Sustainability & Climate Change',
#  'Consulting - Climate and Sustainability - 2022/23 Graduate Program (Brisbane)',
#  'Forensic Analytics - 2023 Graduate Program (Sydney)',
#  'Consultant / Senior Consultant - Strategy - Data & AI',
#  'Data Analyst & Programmer',
#  'Data Scientist (x2)',
#  'Junior Data Engineer Job in Gold Coast',
#  'Junior Python Developer',
#  'Data & Reporting Specialist',
#  'Consulting - Climate and Sustainability - 2022/23 Summer Vacationer Program (Sydney)',
#  'Senior Data Analyst - NSW Data Analytics Centre (DAC)',
#  'Manager _ Senior Manager - Climate Change and Sustainability Services - FS',
#  'Forensic Analytics - 2023 Graduate Program (Canberra)',
#  'Data Analyst',
#  'Data Operations Analyst',
#  'Graduate - Technology Associate - Canberra',
#  'Data Scientist 3-6 month Contract',
#  'Junior Data Analyst',
#  'Data Migration Specialist - Brisbane or Canberra',
#  'Software Developer/Programmer',
#  'Business Analyst',
#  'Software Engineer - Graduate',
#  'Junior Machine Learning Engineer',
#  'Graduate Software Developer',
#  'Business Intelligence Analyst',
#  'Senior Data Scientist',
#  'Graduate Machine Learning (Permanent)',
#  'Data Scientist (Simulation)',
#  'Machine Learning Scientist',
#  'Pawsey Supercomputing Centre Summer Internships',
#  'Software Engineer ML applications',
#  'Sustainability Data Analyst',
#  'Developer Programmer',
#  'Business Intelligence (BI) Developer',
#  'Geospatial Data Analyst',
#  'SVP 2022/2023 - Digital - Data Science',
#  'Data Analyst, Compliance',
#  'Graduate Technology Associate',
#  'Data scientist',
#  'Software Engineer',
#  'Graduate Analyst, Data and Analytics',
#  'Data Masking Specialist',
#  'Risk Advisory - Data & Analytics - 2023 Graduate Program (Canberra)',
#  'Tutors Required for Local and/or Online Lessons',
#  'Superannuation Data Analyst',
#  'Data and Policy Analyst',
#  'Delivery Lead - Data Intelligence',
#  'Data and Reporting Analyst',
#  'Data Centre Technician - Multiple Opportunities',
#  'Junior Commercial Insights Analyst',
#  'Research Associate - Data Science',
#  'Junior Full Stack Developer',
#  'Head of Data Science',
#  'Data Specialist',
#  'Staff Software Engineer (Remote) - Enterprise',
#  'Consulting - Emerging ERP - 2022/23 Summer Vacationer Program (Sydney)',
#  'Data Scientist - Australian Citizen',
#  'Graduate Software Engineer - Sydney 2023',
#  'Alteryx Data Science',
#  'Business Data Analyst - Graduates Welcome to Apply!',
#  'Maximo Data Migration',
#  'Residues Chemist',
#  'Senior Business Analyst',
#  'Systems Administrator',
#  'Instructor - Part Time Data Science',
#  'Data & Analytics Opportunities | Canberra',
#  'Forensic Technology - 2023 Graduate Program (Perth)',
#  'Information Technology Support (FT)',
#  'Data Engineer',
#  'Data Ecology Analyst',
#  'Information Technology Support',
#  'Data & AI Opportunities | Perth',
#  'Junior Data Engineer',
#  'ICT Business Analyst - Data']

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='Job Title', data=df, order=df['Job Title'].value_counts().index)
plt.xticks(rotation=45)
plt.show()

# %%
#simplify job title
def simp_title(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'machine learning' in title.lower():
        return 'machine learning'
    elif 'developer' in title.lower():
        return 'software developer'
    elif 'data masking' in title.lower():
        return 'data masking'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'consulting' in title.lower():
        return 'consulting'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'research' in title.lower() or 'researcher' in title.lower():
        return 'research'
    elif 'business information' in title.lower() or 'bi' in title.lower():
        return 'business information'
    else:
        return 'na'
#difine the function to decide level of these job
def level(title):
    if 'sr' in title.lower() or 'sr.' in title.lower() or 'senior' in title.lower() or 'principal' in title.lower() or 'lead' in title.lower() or 'head' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'junior' in title.lower() or 'jr.' in title.lower():
        return 'junior'
    else:
        return 'na'

# %%
df['job_simp'] = df['Job Title'].apply(simp_title)
df['job_level'] = df['Job Title'].apply(level)

# %%
df.job_level.value_counts()
# Out:
# na        1006
# senior     130
# junior     125
# Name: job_level, dtype: int64

# %%
df.job_simp.value_counts()
# Out:
# na                      407
# data scientist          245
# analyst                 224
# software developer      191
# consulting               76
# business information     51
# machine learning         43
# data engineer            21
# data masking              2
# research                  1
# Name: job_simp, dtype: int64

# %%
plt.figure(figsize=(16,8))
sns.countplot(x='Location', data=df)
plt.xticks(rotation=-45)
plt.show()

# %%
cities = df.Location.value_counts().index.to_list()
len(cities)
# Out:
# 21

# %% [markdown]
# overall there are several jobs located in 29 different cities, i need to find the state of those cities

# %%
#job description length
df['desc_len'] = df['Job Description'].apply(lambda x: len(x))

# %%
df.head()
# Out:
#                                            Job Title  \
# 0  Data Science Graduate/Undergraduate - Immed St...
# 1       Graduate Data Science - Brisbane (Corporate)
# 2  Consulting - Data & AI - 2022/23 Summer Vacati...
# 3                                     Data Scientist
# 4                  Research Associate - Data Science
#
#                  Salary Estimate       Average Salary  \
# 0  $97K - $141K (Glassdoor Est.)  $116,841 /yr (est.)
# 1  $97K - $141K (Glassdoor Est.)  $128,589 /yr (est.)
# 2  $97K - $141K (Glassdoor Est.)   $78,167 /yr (est.)
# 3  $97K - $141K (Glassdoor Est.)  $125,000 /yr (est.)
# 4  $97K - $141K (Glassdoor Est.)  $102,500 /yr (est.)
#
#                                      Job Description  Rating  \
# 0  Be part of the Award Winning CIMIC Graduate Pr...     3.8
# 1  Job Number:\n82295\nWork type:\nPermanent - Fu...     3.7
# 2  Date: 18-Jul-2022\n\nLocation:\nCanberra, ACT,...     4.0
# 3  Job description\nData Scientist Skills\nProgra...    -1.0
# 4  Job no: 510607\nWork type: Full time\nLocation...     4.2
#
#                          Company Name     Location                     Size  \
# 0                    UGL Limited\n3.8  North Shore  5001 to 10000 Employees
# 1                        Aurizon\n3.7     Brisbane   1001 to 5000 Employees
# 2                       Deloitte\n4.0     Canberra         10000+ Employees
# 3            GoTech Solutions Pty Ltd       Sydney                       -1
# 4  University of New South Wales\n4.2       Sydney   1001 to 5000 Employees
#
#    Founded               Type of ownership  ... r_yn ML_yn excel_yn  spark_yn  \
# 0     1984  Subsidiary or Business Segment  ...    1     0        1         0
# 1     2009                Company - Public  ...    1     1        0         0
# 2     1850               Company - Private  ...    1     1        1         0
# 3       -1                Company - Public  ...    1     1        1         0
# 4     1949            College / University  ...    1     1        0         0
#
#    aws_yn graduate_yn  ave_salary        job_simp  job_level  desc_len
# 0       0           1    116841.0              na         na      2319
# 1       0           1    128589.0              na         na      4012
# 2       0           0     78167.0      consulting         na      3348
# 3       0           0    125000.0  data scientist         na      1828
# 4       0           0    102500.0        research         na      6499
#
# [5 rows x 28 columns]

# %% [markdown]
# #### start to visualize datasets

# %%
df.describe()
# Out:
#             Rating      Founded   min_salary   max_salary          age  \
# count  1261.000000  1261.000000  1261.000000  1261.000000  1261.000000
# mean      3.533624  1161.006344    31.734338    37.747026    52.035686
# std       1.576699   950.041519    29.521340    38.192685    68.965516
# min      -1.000000    -1.000000    -1.000000    -1.000000    -1.000000
# 25%       3.800000    -1.000000    -1.000000    -1.000000    -1.000000
# 50%       3.900000  1850.000000    36.000000    36.000000    14.000000
# 75%       4.000000  1984.000000    55.000000    82.000000   117.000000
# max       5.000000  2019.000000    97.000000   141.000000   173.000000
#
#          python_yn    r_yn        ML_yn     excel_yn     spark_yn  \
# count  1261.000000  1261.0  1261.000000  1261.000000  1261.000000
# mean      0.343378     1.0     0.279144     0.348136     0.020619
# std       0.475025     0.0     0.448756     0.476569     0.142160
# min       0.000000     1.0     0.000000     0.000000     0.000000
# 25%       0.000000     1.0     0.000000     0.000000     0.000000
# 50%       0.000000     1.0     0.000000     0.000000     0.000000
# 75%       1.000000     1.0     1.000000     1.000000     0.000000
# max       1.000000     1.0     1.000000     1.000000     1.000000
#
#             aws_yn  graduate_yn     ave_salary      desc_len
# count  1261.000000  1261.000000    1261.000000   1261.000000
# mean      0.051546     0.295797  101050.212530   3522.008723
# std       0.221197     0.456581   44237.402283   1527.683315
# min       0.000000     0.000000      65.000000    114.000000
# 25%       0.000000     0.000000   72849.000000   2836.000000
# 50%       0.000000     0.000000   93247.000000   3426.000000
# 75%       0.000000     1.000000  121491.000000   4497.000000
# max       1.000000     1.000000  240000.000000  12946.000000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Average Salary', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'min_salary',
#        'max_salary', 'company_name', 'age', 'python_yn', 'r_yn', 'ML_yn',
#        'excel_yn', 'spark_yn', 'aws_yn', 'graduate_yn', 'ave_salary',
#        'job_simp', 'job_level', 'desc_len'],
#       dtype='object')

# %%
sns.histplot(data=df, x='Rating')
plt.show()

# %%
sns.histplot(df.ave_salary)
# Out:
# <AxesSubplot:xlabel='ave_salary', ylabel='Count'>

# %%
sns.boxplot(y='Rating', data = df)
# Out:
# <AxesSubplot:ylabel='Rating'>

# %%
sns.boxplot(y='age', data=df)
# Out:
# <AxesSubplot:ylabel='age'>

# %% [markdown]
# correlation map:

# %%
corr = df[['age','ave_salary', 'desc_len', 'Rating']].corr()
corr
# Out:
#                  age  ave_salary  desc_len    Rating
# age         1.000000   -0.115285  0.101476  0.211949
# ave_salary -0.115285    1.000000  0.019452  0.110445
# desc_len    0.101476    0.019452  1.000000  0.073306
# Rating      0.211949    0.110445  0.073306  1.000000

# %%
sns.heatmap(corr, cmap='PuBuGn')
# Out:
# <AxesSubplot:>

# %% [markdown]
# pivot table of data, show the relationship of ave_salary with categorical variables

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Average Salary', 'Job Description',
#        'Rating', 'Company Name', 'Location', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'min_salary',
#        'max_salary', 'company_name', 'age', 'python_yn', 'r_yn', 'ML_yn',
#        'excel_yn', 'spark_yn', 'aws_yn', 'graduate_yn', 'ave_salary',
#        'job_simp', 'job_level', 'desc_len'],
#       dtype='object')

# %%
cat_col = ['Size', 'Location', 'Type of ownership', 'Industry', 'Sector', 
                  'Revenue', 'company_name','python_yn', 'r_yn', 'ML_yn','excel_yn', 'spark_yn', 
                  'aws_yn', 'graduate_yn','job_simp', 'job_level']

# %%
for i in cat_col:
    print('pivot table for: ', i, )
    print(df.pivot_table(index = i, values = 'ave_salary').sort_values('ave_salary', ascending=False))
# Out:
# pivot table for:  Size
#                             ave_salary
# Size
# 1001 to 5000 Employees   119412.717241
# -1                       119131.289474
# 1 to 50 Employees        108060.645833
# 501 to 1000 Employees    102872.894737
# 51 to 200 Employees       98825.852273
# 201 to 500 Employees      98222.533333
# 10000+ Employees          94382.160804
# 5001 to 10000 Employees   85759.659483
# pivot table for:  Location
#                       ave_salary
# Location
# Paddington         128452.000000
# Belconnen          125010.135135
# Canberra           121437.621951
# South Melbourne    120000.000000
# North Shore        116841.000000
# Australia          114456.391813
# Rhodes             111250.000000
# Brisbane           101246.647059
# Sydney              98920.708455
# Remote              98469.166667
# Osborne Park        88746.780488
# North Sydney        86369.000000
# Eight Mile Plains   85000.000000
# Melbourne           84121.126050
# Perth               83533.576271
# Gold Coast          82171.000000
# New South Wales     79724.911392
# Surry Hills         72807.130435
# Mulgrave            59785.000000
# South Australia     50677.000000
# Hobart                115.000000
# pivot table for:  Type of ownership
#                                    ave_salary
# Type of ownership
# Government                      118065.585366
# Company - Public                116041.827586
# Subsidiary or Business Segment  114325.476190
# College / University            102500.000000
# Company - Private               102175.721538
# Self-employed                    94131.250000
# Unknown                          90303.348837
# -1                               78211.000000
# Hospital                         36000.000000
# pivot table for:  Industry
#                                              ave_salary
# Industry
# Internet & Web Services                   142355.574468
# Taxi & Car Services                       128589.000000
# Transportation Equipment Manufacturing    128452.000000
# Investment & Asset Management             123634.125000
# Office Supply & Copy Stores               121491.000000
# Architectural & Engineering Services      120494.000000
# Business Consulting                       120441.226190
# Healthcare Services & Hospitals           119116.292683
# Construction                              116841.000000
# Consumer Electronics & Appliances Stores  111553.000000
# Aerospace & Defence                       111220.000000
# Advertising & Public Relations            106361.107143
# HR Consulting                             106067.500000
# Colleges & Universities                   102500.000000
# Insurance Agencies & Brokerages           102470.000000
# Hotels & Resorts                          102470.000000
# Software Development                       99936.108108
# -1                                         99082.549161
# Enterprise Software & Network Solutions    98346.650000
# Publishing                                 94107.000000
# Department, Clothing & Shoe Stores         93247.000000
# Gambling & Betting                         91378.000000
# Computer Hardware Development              90386.978261
# Consumer Product Manufacturing             90205.000000
# Accounting & Tax                           87968.528302
# Banking & Lending                          87553.250000
# Biotech & Pharmaceuticals                  85000.000000
# Beauty & Personal Accessories Stores       82500.000000
# Research & Development                     81289.000000
# Mining & Metals                            77969.133333
# Information Technology Support Services    77061.602740
# Security & Protective                      74484.000000
# General Merchandise & Superstores          59785.000000
# Food & Beverage Manufacturing              50677.000000
# Energy & Utilities                         45032.500000
# National Services & Agencies               39728.000000
# Education Support & Training Services        155.000000
# pivot table for:  Sector
#                                                 ave_salary
# Sector
# Transportation & Logistics                   128589.000000
# Healthcare                                   119116.292683
# Management & Consulting                      118934.712644
# Construction, Repair & Maintenance Services  116937.131579
# Retail & Wholesale                           116725.951220
# Aerospace & Defence                          111220.000000
# Human Resources & Staffing                   106067.500000
# Media & Communication                        105938.551724
# Insurance                                    102470.000000
# Hotel & Travel Accommodation                 102470.000000
# Information Technology                        99276.139013
# -1                                            98793.387952
# Finance                                       93007.733119
# Arts, Entertainment & Recreation              91378.000000
# Pharmaceutical & Biotechnology                85000.000000
# Manufacturing                                 84943.750000
# Energy, Mining, Utilities                     74094.235294
# Education                                     51327.500000
# Government & Public Administration            39728.000000
# pivot table for:  Revenue
#                                      ave_salary
# Revenue
# $50 to $100 million (USD)         143028.303030
# $2 to $5 billion (USD)            130973.911111
# $100 to $500 million (USD)        122139.075000
# $5 to $10 billion (USD)           113656.823529
# -1                                100788.051056
# $25 to $50 million (USD)           98772.746479
# $10 to $25 million (USD)           93127.600000
# Less than $1 million (USD)         90205.000000
# $10+ billion (USD)                 89294.389744
# $500 million to $1 billion (USD)   68768.000000
# $1 to $5 million (USD)               130.000000
# pivot table for:  company_name
#                              ave_salary
# company_name
# Vertical Scope Group      240000.000000
# MALTEM Australia          170000.000000
# AMP Limited               155763.000000
# Indeed                    153538.461538
# Maltem Australia          150000.000000
# ...                                 ...
# Western Health Australia   36000.000000
# General Assembly             155.000000
# Adactin Group Pty Ltd        155.000000
# CYOS Solutions               130.000000
# Lessons Australia             65.000000
#
# [90 rows x 1 columns]
# pivot table for:  python_yn
#               ave_salary
# python_yn
# 1          105140.826790
# 0           98911.038647
# pivot table for:  r_yn
#         ave_salary
# r_yn
# 1     101050.21253
# pivot table for:  ML_yn
#           ave_salary
# ML_yn
# 1      120266.781250
# 0       93608.812981
# pivot table for:  excel_yn
#              ave_salary
# excel_yn
# 0         109363.750608
# 1          85483.633257
# pivot table for:  spark_yn
#              ave_salary
# spark_yn
# 0         101440.407287
# 1          82515.961538
# pivot table for:  aws_yn
#            ave_salary
# aws_yn
# 1       109071.984615
# 0       100614.246656
# pivot table for:  graduate_yn
#                 ave_salary
# graduate_yn
# 0            101254.345721
# 1            100564.233244
# pivot table for:  job_simp
#                          ave_salary
# job_simp
# data scientist        135260.187755
# business information  130479.137255
# data masking          115000.000000
# software developer    104958.884817
# research              102500.000000
# na                     99846.461916
# machine learning       99817.139535
# data engineer          85691.047619
# consulting             79413.565789
# analyst                64673.656250
# pivot table for:  job_level
#               ave_salary
# job_level
# na         106262.553678
# senior     102823.138462
# junior      57257.448000

# %%
df.to_csv('/Users/liminzhenscc/Documents/study/python_data_analyze/project/2data_sc_salary/glassdoor_jobs_eda.csv')
