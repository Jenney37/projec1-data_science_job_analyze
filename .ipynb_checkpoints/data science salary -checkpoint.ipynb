# %% [markdown]
# ### 1. data cleaning

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR
from sklearn.preprocessing import PolynomialFeatures
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
import sklearn.metrics as skm
from sklearn.model_selection import train_test_split
import operator as op

from sklearn.impute import SimpleImputer

import seaborn as sns

# %%
data = pd.read_csv('/Users/liminzhenscc/Documents/study/python_data_analyze/project/2data_sc_salary/glassdoor_jobs3.csv')
data.head()
# Out:
#                                            Job Title  \
# 0  Data Science Graduate/Undergraduate - Immed St...
# 1       Graduate Data Science - Brisbane (Corporate)
# 2  Consulting - Data & AI - 2022/23 Summer Vacati...
# 3                                     Data Scientist
# 4                  Research Associate - Data Science
#
#                  Salary Estimate  \
# 0  $97K - $141K (Glassdoor Est.)
# 1  $97K - $141K (Glassdoor Est.)
# 2  $97K - $141K (Glassdoor Est.)
# 3  $97K - $141K (Glassdoor Est.)
# 4  $97K - $141K (Glassdoor Est.)
#
#                                      Job Description  Rating  \
# 0  Be part of the Award Winning CIMIC Graduate Pr...     3.8
# 1  Job Number:\n82295\nWork type:\nPermanent - Fu...     3.7
# 2  Date: 18-Jul-2022\n\nLocation:\nCanberra, ACT,...     4.0
# 3  Maltem is a community of 1,200+ passionate ind...     3.8
# 4  Job no: 510607\nWork type: Full time\nLocation...     4.2
#
#                          Company Name     Location                     Size  \
# 0                    UGL Limited\n3.8  North Shore  5001 to 10000 Employees
# 1                        Aurizon\n3.7     Brisbane   1001 to 5000 Employees
# 2                       Deloitte\n4.0     Canberra         10000+ Employees
# 3               MALTEM Australia\n3.8       Sydney   1001 to 5000 Employees
# 4  University of New South Wales\n4.2       Sydney   1001 to 5000 Employees
#
#    Founded               Type of ownership                 Industry  \
# 0     1984  Subsidiary or Business Segment             Construction
# 1     2009                Company - Public      Taxi & Car Services
# 2     1850               Company - Private         Accounting & Tax
# 3     2001               Company - Private      Business Consulting
# 4     1949            College / University  Colleges & Universities
#
#                                         Sector                    Revenue
# 0  Construction, Repair & Maintenance Services   Unknown / Non-Applicable
# 1                   Transportation & Logistics     $2 to $5 billion (USD)
# 2                                      Finance         $10+ billion (USD)
# 3                      Management & Consulting  $50 to $100 million (USD)
# 4                                    Education   Unknown / Non-Applicable

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1173 entries, 0 to 1172
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          1173 non-null   object
#  1   Salary Estimate    1173 non-null   object
#  2   Job Description    1173 non-null   object
#  3   Rating             1173 non-null   float64
#  4   Company Name       1173 non-null   object
#  5   Location           1173 non-null   object
#  6   Size               1173 non-null   object
#  7   Founded            1173 non-null   int64
#  8   Type of ownership  1173 non-null   object
#  9   Industry           1173 non-null   object
#  10  Sector             1173 non-null   object
#  11  Revenue            1173 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 110.1+ KB

# %% [markdown]
# column needed to deal with:
# 1. Salary Estimate
# 2. Company Name
# 3. age(counted via Founded)
# 4. Job Description (data scientist , data analyst, machine learning, data engeneering.
# 5. Size (unknown to -1)

# %% [markdown]
# There are 12 columns, except Founded and Rasting, all other columns are object, we need to do some data cleaning to get useful information that we may need for the final model.

# %%
#dealing with Salary Estimate. get the lowest and maximum value.
salary = data['Salary Estimate'].apply(lambda x: x.split('(')[0])
salary = salary.apply(lambda x: x.replace('K', '').replace('$', ''))
salary
# Out:
# 0        97 - 141
# 1        97 - 141
# 2        97 - 141
# 3        97 - 141
# 4        97 - 141
#            ...
# 1168    106 - 120
# 1169    106 - 120
# 1170    106 - 120
# 1171    106 - 120
# 1172    106 - 120
# Name: Salary Estimate, Length: 1173, dtype: object

# %%
data['min_salary'] = salary.apply(lambda x: int(x.split('-')[0]))
data['max_salary'] = salary.apply(lambda x: int(x.split('-')[-1]))
data['ave_salary'] = (data.min_salary+data.max_salary)/2
data.head()
# Out:
#                                            Job Title  \
# 0  Data Science Graduate/Undergraduate - Immed St...
# 1       Graduate Data Science - Brisbane (Corporate)
# 2  Consulting - Data & AI - 2022/23 Summer Vacati...
# 3                                     Data Scientist
# 4                  Research Associate - Data Science
#
#                  Salary Estimate  \
# 0  $97K - $141K (Glassdoor Est.)
# 1  $97K - $141K (Glassdoor Est.)
# 2  $97K - $141K (Glassdoor Est.)
# 3  $97K - $141K (Glassdoor Est.)
# 4  $97K - $141K (Glassdoor Est.)
#
#                                      Job Description  Rating  \
# 0  Be part of the Award Winning CIMIC Graduate Pr...     3.8
# 1  Job Number:\n82295\nWork type:\nPermanent - Fu...     3.7
# 2  Date: 18-Jul-2022\n\nLocation:\nCanberra, ACT,...     4.0
# 3  Maltem is a community of 1,200+ passionate ind...     3.8
# 4  Job no: 510607\nWork type: Full time\nLocation...     4.2
#
#                          Company Name     Location                     Size  \
# 0                    UGL Limited\n3.8  North Shore  5001 to 10000 Employees
# 1                        Aurizon\n3.7     Brisbane   1001 to 5000 Employees
# 2                       Deloitte\n4.0     Canberra         10000+ Employees
# 3               MALTEM Australia\n3.8       Sydney   1001 to 5000 Employees
# 4  University of New South Wales\n4.2       Sydney   1001 to 5000 Employees
#
#    Founded               Type of ownership                 Industry  \
# 0     1984  Subsidiary or Business Segment             Construction
# 1     2009                Company - Public      Taxi & Car Services
# 2     1850               Company - Private         Accounting & Tax
# 3     2001               Company - Private      Business Consulting
# 4     1949            College / University  Colleges & Universities
#
#                                         Sector                    Revenue  \
# 0  Construction, Repair & Maintenance Services   Unknown / Non-Applicable
# 1                   Transportation & Logistics     $2 to $5 billion (USD)
# 2                                      Finance         $10+ billion (USD)
# 3                      Management & Consulting  $50 to $100 million (USD)
# 4                                    Education   Unknown / Non-Applicable
#
#    min_salary  max_salary  ave_salary
# 0          97         141       119.0
# 1          97         141       119.0
# 2          97         141       119.0
# 3          97         141       119.0
# 4          97         141       119.0

# %%
#delete rating after company name
data['company_name'] = data['Company Name'].apply(lambda x: x.split('\n')[0])
data.head()
# Out:
#                                            Job Title  \
# 0  Data Science Graduate/Undergraduate - Immed St...
# 1       Graduate Data Science - Brisbane (Corporate)
# 2  Consulting - Data & AI - 2022/23 Summer Vacati...
# 3                                     Data Scientist
# 4                  Research Associate - Data Science
#
#                  Salary Estimate  \
# 0  $97K - $141K (Glassdoor Est.)
# 1  $97K - $141K (Glassdoor Est.)
# 2  $97K - $141K (Glassdoor Est.)
# 3  $97K - $141K (Glassdoor Est.)
# 4  $97K - $141K (Glassdoor Est.)
#
#                                      Job Description  Rating  \
# 0  Be part of the Award Winning CIMIC Graduate Pr...     3.8
# 1  Job Number:\n82295\nWork type:\nPermanent - Fu...     3.7
# 2  Date: 18-Jul-2022\n\nLocation:\nCanberra, ACT,...     4.0
# 3  Maltem is a community of 1,200+ passionate ind...     3.8
# 4  Job no: 510607\nWork type: Full time\nLocation...     4.2
#
#                          Company Name     Location                     Size  \
# 0                    UGL Limited\n3.8  North Shore  5001 to 10000 Employees
# 1                        Aurizon\n3.7     Brisbane   1001 to 5000 Employees
# 2                       Deloitte\n4.0     Canberra         10000+ Employees
# 3               MALTEM Australia\n3.8       Sydney   1001 to 5000 Employees
# 4  University of New South Wales\n4.2       Sydney   1001 to 5000 Employees
#
#    Founded               Type of ownership                 Industry  \
# 0     1984  Subsidiary or Business Segment             Construction
# 1     2009                Company - Public      Taxi & Car Services
# 2     1850               Company - Private         Accounting & Tax
# 3     2001               Company - Private      Business Consulting
# 4     1949            College / University  Colleges & Universities
#
#                                         Sector                    Revenue  \
# 0  Construction, Repair & Maintenance Services   Unknown / Non-Applicable
# 1                   Transportation & Logistics     $2 to $5 billion (USD)
# 2                                      Finance         $10+ billion (USD)
# 3                      Management & Consulting  $50 to $100 million (USD)
# 4                                    Education   Unknown / Non-Applicable
#
#    min_salary  max_salary  ave_salary                   company_name
# 0          97         141       119.0                    UGL Limited
# 1          97         141       119.0                        Aurizon
# 2          97         141       119.0                       Deloitte
# 3          97         141       119.0               MALTEM Australia
# 4          97         141       119.0  University of New South Wales

# %%
data['Revenue'] = data['Revenue'].apply(lambda x: x if 'unknown' not in x.lower() else -1)

# %%
data.Revenue.head()
# Out:
# 0                           -1
# 1       $2 to $5 billion (USD)
# 2           $10+ billion (USD)
# 3    $50 to $100 million (USD)
# 4                           -1
# Name: Revenue, dtype: object

# %%
#age of company
data['age'] = data.Founded.apply(lambda x: x if x==-1 else 2022-x)
data.head()
# Out:
#                                            Job Title  \
# 0  Data Science Graduate/Undergraduate - Immed St...
# 1       Graduate Data Science - Brisbane (Corporate)
# 2  Consulting - Data & AI - 2022/23 Summer Vacati...
# 3                                     Data Scientist
# 4                  Research Associate - Data Science
#
#                  Salary Estimate  \
# 0  $97K - $141K (Glassdoor Est.)
# 1  $97K - $141K (Glassdoor Est.)
# 2  $97K - $141K (Glassdoor Est.)
# 3  $97K - $141K (Glassdoor Est.)
# 4  $97K - $141K (Glassdoor Est.)
#
#                                      Job Description  Rating  \
# 0  Be part of the Award Winning CIMIC Graduate Pr...     3.8
# 1  Job Number:\n82295\nWork type:\nPermanent - Fu...     3.7
# 2  Date: 18-Jul-2022\n\nLocation:\nCanberra, ACT,...     4.0
# 3  Maltem is a community of 1,200+ passionate ind...     3.8
# 4  Job no: 510607\nWork type: Full time\nLocation...     4.2
#
#                          Company Name     Location                     Size  \
# 0                    UGL Limited\n3.8  North Shore  5001 to 10000 Employees
# 1                        Aurizon\n3.7     Brisbane   1001 to 5000 Employees
# 2                       Deloitte\n4.0     Canberra         10000+ Employees
# 3               MALTEM Australia\n3.8       Sydney   1001 to 5000 Employees
# 4  University of New South Wales\n4.2       Sydney   1001 to 5000 Employees
#
#    Founded               Type of ownership                 Industry  \
# 0     1984  Subsidiary or Business Segment             Construction
# 1     2009                Company - Public      Taxi & Car Services
# 2     1850               Company - Private         Accounting & Tax
# 3     2001               Company - Private      Business Consulting
# 4     1949            College / University  Colleges & Universities
#
#                                         Sector                    Revenue  \
# 0  Construction, Repair & Maintenance Services                         -1
# 1                   Transportation & Logistics     $2 to $5 billion (USD)
# 2                                      Finance         $10+ billion (USD)
# 3                      Management & Consulting  $50 to $100 million (USD)
# 4                                    Education                         -1
#
#    min_salary  max_salary  ave_salary                   company_name  age
# 0          97         141       119.0                    UGL Limited   38
# 1          97         141       119.0                        Aurizon   13
# 2          97         141       119.0                       Deloitte  172
# 3          97         141       119.0               MALTEM Australia   21
# 4          97         141       119.0  University of New South Wales   73

# %%
data['python_yn'] = data['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
data['r_yn'] = data['Job Description'].apply(lambda x: 1 if 'r' in x.lower() else 0)
data['ML_yn'] = data['Job Description'].apply(lambda x: 1 if 'machine learning' in x.lower() else 0)
data['excel_yn'] = data['Job Description'].apply(lambda x: 1 if 'excel' in x.lower() else 0)
data['spark_yn'] = data['Job Description'].apply(lambda x: 1 if 'spark' in x.lower() else 0)
data['aws_yn'] = data['Job Description'].apply(lambda x: 1 if 'aws' in x.lower() else 0)

# %%
data['graduate_yn'] = data['Job Title'].apply(lambda x: 1 if 'graduate' in x.lower() else 0)
data.graduate_yn.value_counts()
# Out:
# 0    941
# 1    232
# Name: graduate_yn, dtype: int64

# %%
data.Size = data['Size'].apply(lambda x: x if 'unknown' not in x.lower() else -1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1173 entries, 0 to 1172
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          1173 non-null   object
#  1   Salary Estimate    1173 non-null   object
#  2   Job Description    1173 non-null   object
#  3   Rating             1173 non-null   float64
#  4   Company Name       1173 non-null   object
#  5   Location           1173 non-null   object
#  6   Size               1173 non-null   object
#  7   Founded            1173 non-null   int64
#  8   Type of ownership  1173 non-null   object
#  9   Industry           1173 non-null   object
#  10  Sector             1173 non-null   object
#  11  Revenue            1173 non-null   object
#  12  min_salary         1173 non-null   int64
#  13  max_salary         1173 non-null   int64
#  14  ave_salary         1173 non-null   float64
#  15  company_name       1173 non-null   object
#  16  age                1173 non-null   int64
#  17  python_yn          1173 non-null   int64
#  18  r_yn               1173 non-null   int64
#  19  ML_yn              1173 non-null   int64
#  20  excel_yn           1173 non-null   int64
#  21  spark_yn           1173 non-null   int64
#  22  aws_yn             1173 non-null   int64
#  23  graduate_yn        1173 non-null   int64
# dtypes: float64(2), int64(11), object(11)
# memory usage: 220.1+ KB

# %%
data.to_csv('/Users/liminzhenscc/Documents/study/python_data_analyze/project/2data_sc_salary/glassdoor_jobs_cleaned.csv')
